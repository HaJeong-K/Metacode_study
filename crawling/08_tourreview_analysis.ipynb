# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
plt.rc('font', family = 'Malgun Gothic')

# %%
df = pd.read_csv('tour_review_backup.csv')
df
# Out:
#      rating        user      category  age        date  \
# 0       5.0    oga*****    가족여행으로 좋아요  50대  2024.03.16
# 1       5.0   all******    친구모임으로 좋아요  50대  2024.03.14
# 2       4.0      크리스피라왓    가족여행으로 좋아요  30대  2024.03.12
# 3       5.0     jju****    가족여행으로 좋아요  50대  2024.03.12
# 4       5.0        7711    친구모임으로 좋아요  60대  2024.03.08
# ..      ...         ...           ...  ...         ...
# 885     5.0          꽁심    친구모임으로 좋아요  60대  2022.10.14
# 886     5.0  dhr*******    커플여행으로 좋아요  30대  2022.10.14
# 887     5.0     scl****    가족여행으로 좋아요  30대  2022.10.13
# 888     4.8          도비    가족여행으로 좋아요  20대  2022.10.04
# 889     5.0       apd**  나홀로 여행으로 좋아요  40대  2022.09.28
#
#                                                 review  \
# 0    안녕하세요 윤진연 가이드님과 함께한 규슈 여행은 환상이았습니다 가이드님의 배려와 세...
# 1    일본어에 관심이있어 독학하던중 친한 언니들과 함께 한 여행인데 너무도 따스한 추억으...
# 2    유튜브나 블로그에 후기올릴 예정 음식 별로임(우동 카레 가이세키 다 별로) 특히 가...
# 3    더 나이 드시전에 친정엄마와 함께 부랴부랴 떠난 일정이었지만 세심하고 배려있는 정 ...
# 4    좋은후배와 처음간 여행으로 여유롭게 추억을 간직하고 돌아왔어요 사가의 작은마을이지만...
# ..                                                 ...
# 885                                         모든게 만족~~!!
# 886  김은주 가이드님의 친절하고 해박한 설명에 눈 뿐만아니라 머리(지식)도 줄거운 여행이...
# 887  코로나 이후 가족여행으로 예약하였습니다 비자풀리기 바로 직전이라거 비자신청하고 비용...
# 888  엄마랑 모녀여행 일본 개인여행 풀리기전에 너무 쾌적하게 다녀왔어요 조세호 가이드님 ...
# 889  김범준 가이드님이 제일 고생하셨고 일정 마무리까지 너무 감사했습니다. 100점 만점...
#
#                                            review_cate
# 0    호텔에서 쉬기 좋아요\n일정이 알차요\n현지 음식이 맛있어요\n가격이 합리적이에요\...
# 1    호텔 부대시설이 좋아요\n일정이 알차요\n현지 음식이 다양해요\n가격이 합리적이에요...
# 2                                   객실 뷰가 좋아요\n일정이 알차요
# 3    객실이 깨끗해요\n일정이 알차요\n현지 음식이 다양해요\n가격이 합리적이에요\n가이...
# 4    호텔 부대시설이 좋아요\n일정이 여유로워요\n식당이 청결해요\n가격이 합리적이에요\...
# ..                                                 ...
# 885                                                NaN
# 886                                                NaN
# 887                                                NaN
# 888                                                NaN
# 889                                                NaN
#
# [890 rows x 7 columns]

# %%
# 1. 카테고리별 리뷰 수 시각화
# 각 카테고리(가족여행, 친구모임, 커플여행 등) 별로 리뷰 수를 시각화해보고, 어떤 여행 유형이 가장 많은지 알아봅니다.

# 카테고리별 리뷰 수 계산
category_count = df['category'].value_counts()
category_count
# Out:
# 가족여행으로 좋아요       572
# 친구모임으로 좋아요       133
# 커플여행으로 좋아요       100
# 아동동반 여행으로 좋아요     31
# 나홀로 여행으로 좋아요      29
# 기타                24
# 허니문으로 좋아요          1
# Name: category, dtype: int64

# %%
plt.figure(figsize = (15, 6))
category_count.plot(kind = 'bar', color = 'skyblue')

plt.title('카테고리별 리뷰 수')
plt.xlabel('카테고리')
plt.ylabel('리뷰 수')
plt.xticks(rotation = 25)
plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()

# %%
# 날짜별 리뷰 분포 시각화
# 날짜별로 리뷰가 어떻게 분포되어있는지 시각화해서 특정 날짜에 리뷰가 많거나, 적은 때를 확인
# 날짜를 datetime 형식으로 변환
import matplotlib.dates as mdates

df['date'] = pd.to_datetime(df['date'])

# %%
# 날짜별 리뷰 수 계산
date_counts = df['date'].value_counts().sort_index()

plt.figure(figsize = (30, 10))
sns.lineplot(x = date_counts.index, y = date_counts.values, marker = 'o', color = 'orange')

plt.title('날짜별 리뷰 수')
plt.xlabel('날짜')
plt.ylabel('리뷰 수')

plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()

# %%
# 날짜별 리뷰 수 계산
date_counts = df['date'].value_counts().sort_index()

plt.figure(figsize = (30, 10))
sns.lineplot(x = date_counts.index, y = date_counts.values, marker = 'o', color = 'orange')

plt.title('날짜별 리뷰 수')
plt.xlabel('날짜')
plt.ylabel('리뷰 수')

# xticks에 날짜 형식 설정
date_format = mdates.DateFormatter('%Y-%m')
plt.gca().xaxis.set_major_formatter(date_format)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation = 50)

plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()

# %%
# 3. 나이별 평균 평점 비교
# 각 연령대별로 평균 평점을 비교해서 어떤 연령대가 평균적으로 좋은 리뷰를 남기는지 확인합니다.

# 나이별 평균 평점 계산
age_rating = df.groupby('age')['rating'].mean().sort_values()

# 시각화
plt.figure(figsize = (10, 6))
sns.barplot(x = age_rating.index, y = age_rating.values, palette = 'viridis')

plt.title('나이별 평균 평점')
plt.xlabel('나이')
plt.ylabel('평균 평점')

plt.xticks(rotation = 45)
plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()

# %%
# 나이대에 다른 값이 들어갔을 경우 예시
# df_age = df[df['age'].str.endswith('대')]
# 평점이 null값이 아닌 경우만
# df_age = df_age[df_age['rating'].notnull()]

# 나이별 평균 평점 계산
df = df[df['rating'].notnull()]
age_rating_new = df.groupby('age')['rating'].mean().sort_values()

# 시각화
plt.figure(figsize = (10, 6))
sns.barplot(x = age_rating_new.index, y = age_rating_new.values, palette = 'viridis')

plt.title('나이별 평균 평점')
plt.xlabel('나이')
plt.ylabel('평균 평점')

# y축 범위 설정
plt.ylim(4, 5)

plt.xticks(rotation = 0)
plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()

# %%
age_rating_new = age_rating_new.sort_index()

# %%
# 시각화
plt.figure(figsize = (10, 6))
sns.barplot(x = age_rating_new.index, y = age_rating_new.values, palette = 'viridis')

plt.title('나이별 평균 평점')
plt.xlabel('나이')
plt.ylabel('평균 평점')

# y축 범위 설정
plt.ylim(4, 5)

plt.xticks(rotation = 0)
plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()
